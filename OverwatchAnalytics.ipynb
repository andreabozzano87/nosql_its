# %% [markdown]
# # Overwatch Competitive Analytics

# %% [markdown]
# **Prima parte**: connessione a MongoDB

# %%
from pymongo import MongoClient

# Connessione al database MongoDB
client = MongoClient("mongodb+srv://<usr>:<pw>@<host>")
db = client["Overwatch2"]
season1 = db["SEASON1"]
season2 = db["SEASON2"]
season3 = db["SEASON3"]
season4 = db["SEASON4"]

# %% [markdown]
# **Seconda parte**: creiamo una collection temporanea con tutti i dati

# %%
# Unire le collezioni delle quattro stagioni
all_seasons = db["ALL_SEASONS"]
all_seasons.delete_many({})  # Pulire la collezione temporanea se esiste già

# Creare una lista per i documenti di tutte le stagioni
documents = []

# Funzione per aggiungere stagione al documento
def add_season_info(doc, season):
    doc["Season"] = season
    return doc

for collection, season_name in zip([season1, season2, season3, season4], ["SEASON1", "SEASON2", "SEASON3", "SEASON4"]):
    documents.extend([add_season_info(doc, season_name) for doc in collection.find()])

# Inserire tutti i documenti in una sola operazione
all_seasons.insert_many(documents)
# Out:
# InsertManyResult([ObjectId('66a0fb4033e7e17b516b12e0'), ObjectId('66a0fb4033e7e17b516b12e1'), ObjectId('66a0fb4033e7e17b516b12e2'), ObjectId('66a0fb4033e7e17b516b12e3'), ObjectId('66a0fb4033e7e17b516b12e4'), ObjectId('66a0fb4033e7e17b516b12e5'), ObjectId('66a0fb4033e7e17b516b12e6'), ObjectId('66a0fb4033e7e17b516b12e7'), ObjectId('66a0fb4033e7e17b516b12e8'), ObjectId('66a0fb4033e7e17b516b12e9'), ObjectId('66a0fb4033e7e17b516b12ea'), ObjectId('66a0fb4033e7e17b516b12eb'), ObjectId('66a0fb4033e7e17b516b12ec'), ObjectId('66a0fb4033e7e17b516b12ed'), ObjectId('66a0fb4033e7e17b516b12ee'), ObjectId('66a0fb4033e7e17b516b12ef'), ObjectId('66a0fb4033e7e17b516b12f0'), ObjectId('66a0fb4033e7e17b516b12f1'), ObjectId('66a0fb4033e7e17b516b12f2'), ObjectId('66a0fb4033e7e17b516b12f3'), ObjectId('66a0fb4033e7e17b516b12f4'), ObjectId('66a0fb4033e7e17b516b12f5'), ObjectId('66a0fb4033e7e17b516b12f6'), ObjectId('66a0fb4033e7e17b516b12f7'), ObjectId('66a0fb4033e7e17b516b12f8'), ObjectId('66a0fb4033e7e17b516b12f9'), ObjectId('66a0fb4033e7e17b516b12fa'), ObjectId('66a0fb4033e7e17b516b12fb'), ObjectId('66a0fb4033e7e17b516b12fc'), ObjectId('66a0fb4033e7e17b516b12fd'), ObjectId('66a0fb4033e7e17b516b12fe'), ObjectId('66a0fb4033e7e17b516b12ff'), ObjectId('66a0fb4033e7e17b516b1300'), ObjectId('66a0fb4033e7e17b516b1301'), ObjectId('66a0fb4033e7e17b516b1302'), ObjectId('66a0fb4033e7e17b516b1303'), ObjectId('66a0fb4033e7e17b516b1304'), ObjectId('66a0fb4033e7e17b516b1305'), ObjectId('66a0fb4033e7e17b516b1306'), ObjectId('66a0fb4033e7e17b516b1307'), ObjectId('66a0fb4033e7e17b516b1308'), ObjectId('66a0fb4033e7e17b516b1309'), ObjectId('66a0fb4033e7e17b516b130a'), ObjectId('66a0fb4033e7e17b516b130b'), ObjectId('66a0fb4033e7e17b516b130c'), ObjectId('66a0fb4033e7e17b516b130d'), ObjectId('66a0fb4033e7e17b516b130e'), ObjectId('66a0fb4033e7e17b516b130f'), ObjectId('66a0fb4033e7e17b516b1310'), ObjectId('66a0fb4033e7e17b516b1311'), ObjectId('66a0fb4033e7e17b516b1312'), ObjectId('66a0fb4033e7e17b516b1313'), ObjectId('66a0fb4033e7e17b516b1314'), ObjectId('66a0fb4033e7e17b516b1315'), ObjectId('66a0fb4033e7e17b516b1316'), ObjectId('66a0fb4033e7e17b516b1317'), ObjectId('66a0fb4033e7e17b516b1318'), ObjectId('66a0fb4033e7e17b516b1319'), ObjectId('66a0fb4033e7e17b516b131a'), ObjectId('66a0fb4033e7e17b516b131b'), ObjectId('66a0fb4033e7e17b516b131c'), ObjectId('66a0fb4033e7e17b516b131d'), ObjectId('66a0fb4033e7e17b516b131e'), ObjectId('66a0fb4033e7e17b516b131f'), ObjectId('66a0fb4033e7e17b516b1320'), ObjectId('66a0fb4033e7e17b516b1321'), ObjectId('66a0fb4033e7e17b516b1322'), ObjectId('66a0fb4033e7e17b516b1323'), ObjectId('66a0fb4033e7e17b516b1324'), ObjectId('66a0fb4033e7e17b516b1325'), ObjectId('66a0fb4033e7e17b516b1326'), ObjectId('66a0fb4033e7e17b516b1327'), ObjectId('66a0fb4033e7e17b516b1328'), ObjectId('66a0fb4033e7e17b516b1329'), ObjectId('66a0fb4033e7e17b516b132a'), ObjectId('66a0fb4033e7e17b516b132b'), ObjectId('66a0fb4033e7e17b516b132c'), ObjectId('66a0fb4033e7e17b516b132d'), ObjectId('66a0fb4033e7e17b516b132e'), ObjectId('66a0fb4033e7e17b516b132f'), ObjectId('66a0fb4033e7e17b516b1330'), ObjectId('66a0fb4033e7e17b516b1331'), ObjectId('66a0fb4033e7e17b516b1332'), ObjectId('66a0fb4033e7e17b516b1333'), ObjectId('66a0fb4033e7e17b516b1334'), ObjectId('66a0fb4033e7e17b516b1335'), ObjectId('66a0fb4033e7e17b516b1336'), ObjectId('66a0fb4033e7e17b516b1337'), ObjectId('66a0fb4033e7e17b516b1338'), ObjectId('66a0fb4033e7e17b516b1339'), ObjectId('66a0fb4033e7e17b516b133a'), ObjectId('66a0fb4033e7e17b516b133b'), ObjectId('66a0fb4033e7e17b516b133c'), ObjectId('66a0fb4033e7e17b516b133d'), ObjectId('66a0fb4033e7e17b516b133e'), ObjectId('66a0fb4033e7e17b516b133f'), ObjectId('66a0fb4033e7e17b516b1340'), ObjectId('66a0fb4033e7e17b516b1341'), ObjectId('66a0fb4033e7e17b516b1342'), ObjectId('66a0fb4033e7e17b516b1343'), ObjectId('66a0fb4033e7e17b516b1344'), ObjectId('66a0fb4033e7e17b516b1345'), ObjectId('66a0fb4033e7e17b516b1346'), ObjectId('66a0fb4033e7e17b516b1347'), ObjectId('66a0fb4033e7e17b516b ...

# %% [markdown]
# **Terza parte**: analisi con aggregazioni
# Utilizzare l'aggregation framework per calcolare le medie di `KDA Ratio`, `Win Rate, %`, `Damage / 10min`, `Healing / 10min`, `Deaths / 10min` per ciascun eroe.

# %%
pipelineTotal = [
    {"$group": {
        "_id": "$Hero",
        "avg_KDA_Ratio": {"$avg": "$KDA Ratio"},
        "avg_Win_Rate": {"$avg": "$Win Rate, %"},
        "avg_Damage_per_10min": {"$avg": "$Damage / 10min"},
        "avg_Healing_per_10min": {"$avg": "$Healing / 10min"},
        "avg_Deaths_per_10min": {"$avg": "$Deaths / 10min"}
    }},
    {"$sort": {"avg_Win_Rate": -1}}
]

result = all_seasons.aggregate(pipelineTotal)
for doc in result:
    print(doc)
# Out:
# {'_id': 'Torbjorn', 'avg_KDA_Ratio': 3.1193750000000002, 'avg_Win_Rate': 53.4746875, 'avg_Damage_per_10min': 9491.0625, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 6.9643749999999995}
# {'_id': 'Symmetra', 'avg_KDA_Ratio': 3.575, 'avg_Win_Rate': 52.545625, 'avg_Damage_per_10min': 8287.34375, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 8.020625}
# {'_id': 'Ramattra', 'avg_KDA_Ratio': 3.7570833333333336, 'avg_Win_Rate': 51.03, 'avg_Damage_per_10min': 9559.291666666666, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 6.655833333333334}
# {'_id': 'Reinhardt', 'avg_KDA_Ratio': 3.02, 'avg_Win_Rate': 50.808125, 'avg_Damage_per_10min': 8002.125, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 7.125625}
# {'_id': 'Doomfist', 'avg_KDA_Ratio': 3.2421875, 'avg_Win_Rate': 50.2528125, 'avg_Damage_per_10min': 7659.1875, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 7.80875}
# {'_id': 'Zenyatta', 'avg_KDA_Ratio': 5.12, 'avg_Win_Rate': 49.9228125, 'avg_Damage_per_10min': 4802.15625, 'avg_Healing_per_10min': 6199.125, 'avg_Deaths_per_10min': 7.25125}
# {'_id': 'Sigma', 'avg_KDA_Ratio': 4.771875, 'avg_Win_Rate': 49.873125, 'avg_Damage_per_10min': 9701.0, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 5.3153125}
# {'_id': 'Genji', 'avg_KDA_Ratio': 2.494375, 'avg_Win_Rate': 49.6384375, 'avg_Damage_per_10min': 7316.71875, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 8.2484375}
# {'_id': 'Mei', 'avg_KDA_Ratio': 3.8953125, 'avg_Win_Rate': 49.63625, 'avg_Damage_per_10min': 6918.59375, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 7.34}
# {'_id': 'Lucio', 'avg_KDA_Ratio': 3.7971875, 'avg_Win_Rate': 49.445, 'avg_Damage_per_10min': 3525.0, 'avg_Healing_per_10min': 7531.75, 'avg_Deaths_per_10min': 7.5043750000000005}
# {'_id': 'Brigitte', 'avg_KDA_Ratio': 4.3990625, 'avg_Win_Rate': 49.2875, 'avg_Damage_per_10min': 3605.53125, 'avg_Healing_per_10min': 7801.5625, 'avg_Deaths_per_10min': 8.0696875}
# {'_id': 'Ana', 'avg_KDA_Ratio': 4.1340625, 'avg_Win_Rate': 49.090625, 'avg_Damage_per_10min': 2576.0, 'avg_Healing_per_10min': 8113.0625, 'avg_Deaths_per_10min': 6.2778125}
# {'_id': 'Junker Queen', 'avg_KDA_Ratio': 4.139375, 'avg_Win_Rate': 48.8415625, 'avg_Damage_per_10min': 8748.65625, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 7.116875}
# {'_id': 'Mercy', 'avg_KDA_Ratio': 3.8440625, 'avg_Win_Rate': 48.526875000000004, 'avg_Damage_per_10min': 330.09375, 'avg_Healing_per_10min': 8773.125, 'avg_Deaths_per_10min': 6.5784375}
# {'_id': 'Pharah', 'avg_KDA_Ratio': 2.9340625, 'avg_Win_Rate': 48.213125, 'avg_Damage_per_10min': 9092.09375, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 8.728125}
# {'_id': 'Ashe', 'avg_KDA_Ratio': 2.62875, 'avg_Win_Rate': 47.8490625, 'avg_Damage_per_10min': 8420.5, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 7.780625}
# {'_id': 'Widowmaker', 'avg_KDA_Ratio': 2.6, 'avg_Win_Rate': 47.7759375, 'avg_Damage_per_10min': 5860.375, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 8.0009375}
# {'_id': 'Reaper', 'avg_KDA_Ratio': 2.6765625, 'avg_Win_Rate': 47.75625, 'avg_Damage_per_10min': 8017.96875, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 8.2803125}
# {'_id': 'Kiriko', 'avg_KDA_Ratio': 4.7003125, 'avg_Win_Rate': 47.715625, 'avg_Damage_per_10min': 2345.875, 'avg_Healing_per_10min': 8528.28125, 'avg_Deaths_per_10min': 6.118125}
# {'_id': 'Soldier: 76', 'avg_KDA_Ratio': 2.9184375, 'avg_Win_Rate': 47.3440625, 'avg_Damage_per_10min': 8945.84375, 'avg_Healing_per_10min': 1345.5625, 'avg_Deaths_per_10min': 8.425}
# {'_id': 'D.Va', 'avg_KDA_Ratio': 6.1225, 'avg_Win_Rate': 47.3303125, 'avg_Damage_per_10min': 8279.15625, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 5.603125}
# {'_id': 'Moira', 'avg_KDA_Ratio': 5.91625, 'avg_Win_Rate': 47.210625, 'avg_Damage_per_10min': 5231.4375, 'avg_Healing_per_10min': 9106.84375, 'avg_Deaths_per_10min': 6.3928125}
# {'_id': 'Echo', 'avg_KDA_Ratio': 2.629375, 'avg_Win_Rate': 47.165625, 'avg_Damage_per_10min': 8164.25, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 8.2184375}
# {'_id': 'Tracer', 'avg_KDA_Ratio': 2.465625, 'avg_Win_Rate': 47.1165625, 'avg_Damage_per_10min': 6595.625, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 8.3065625}
# {'_id': 'Hanzo', 'avg_KDA_Ratio': 2.96875, 'avg_Win_Rate': 46.6190625, 'avg_Damage_per_10min': 7554.46875, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 8.1275}
# {'_id': 'Bastion', 'avg_KDA_Ratio': 2.69125, 'avg_Win_Rate': 46.5203125, 'avg_Damage_per_10min': 9990.0, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 8.45125}
# {'_id': 'Junkrat', 'avg_KDA_Ratio': 2.5334375, 'avg_Win_Rate': 46.3503125, 'avg_Damage_per_10min': 8227.9375, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 8.5290625}
# {'_id': 'Baptiste', 'avg_KDA_Ratio': 4.30625, 'avg_Win_Rate': 46.289375, 'avg_Damage_per_10min': 3548.3125, 'avg_Healing_per_10min': 8568.9375, 'avg_Deaths_per_10min': 6.7890625}
# {'_id': 'Zarya', 'avg_KDA_Ratio': 4.4240625, 'avg_Win_Rate': 45.82875, 'avg_Damage_per_10min': 9316.53125, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 6.444375}
# {'_id': 'Cassidy', 'avg_KDA_Ratio': 2.1778125, 'avg_Win_Rate': 45.7709375, 'avg_Damage_per_10min': 8035.5625, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 8.6709375}
# {'_id': 'Wrecking Ball', 'avg_KDA_Ratio': 4.3284375, 'avg_Win_Rate': 45.2, 'avg_Damage_per_10min': 7499.65625, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 6.2546875}
# {'_id': 'Sojourn', 'avg_KDA_Ratio': 2.8846875, 'avg_Win_Rate': 44.3253125, 'avg_Damage_per_10min': 8407.0625, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 8.17375}
# {'_id': 'Winston', 'avg_KDA_Ratio': 3.8046875, 'avg_Win_Rate': 44.2284375, 'avg_Damage_per_10min': 7632.1875, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 7.1}
# {'_id': 'Orisa', 'avg_KDA_Ratio': 3.585625, 'avg_Win_Rate': 43.8721875, 'avg_Damage_per_10min': 9132.59375, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 7.05}
# {'_id': 'Sombra', 'avg_KDA_Ratio': 4.6034375, 'avg_Win_Rate': 42.6409375, 'avg_Damage_per_10min': 5376.6875, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 6.229375}
# {'_id': 'Roadhog', 'avg_KDA_Ratio': 3.7490625, 'avg_Win_Rate': 41.9615625, 'avg_Damage_per_10min': 7982.40625, 'avg_Healing_per_10min': None, 'avg_Deaths_per_10min': 6.735625}
# {'_id': 'Lifeweaver', 'avg_KDA_Ratio': 3.3925, 'avg_Win_Rate': 38.455, 'avg_Damage_per_10min': 860.625, 'avg_Healing_per_10min': 8712.625, 'avg_Deaths_per_10min': 6.1075}

# %% [markdown]
# Trovare l'eroe con il tasso di vittoria più alto e quello con il più basso

# %%
pipeline = [
    {"$group": {
        "_id": "$Hero",
        "avg_Win_Rate": {"$avg": "$Win Rate, %"}
    }},
    {"$sort": {"avg_Win_Rate": -1}},
    {"$limit": 1}
]

highest_win_rate = list(all_seasons.aggregate(pipeline))[0]
print(f"Eroe con il tasso di vittoria più alto: {highest_win_rate}")

pipeline[1]["$sort"]["avg_Win_Rate"] = 1
lowest_win_rate = list(all_seasons.aggregate(pipeline))[0]
print(f"Eroe con il tasso di vittoria più basso: {lowest_win_rate}")
# Out:
# Eroe con il tasso di vittoria più alto: {'_id': 'Torbjorn', 'avg_Win_Rate': 53.4746875}
# Eroe con il tasso di vittoria più basso: {'_id': 'Lifeweaver', 'avg_Win_Rate': 38.455}

# %% [markdown]
# Creare un indice sui campi `Hero` e `Role`

# %%
all_seasons.create_index([("Hero", 1)])
all_seasons.create_index([("Role", 1)])
# Out:
# 'Role_1'

# %% [markdown]
# Eseguire una query per trovare tutti i dati degli eroi di ruolo Support

# %%
support_heroes = all_seasons.find({"Role": "Support"}).explain()
print(support_heroes)
# Out:
# {'explainVersion': '1', 'queryPlanner': {'namespace': 'Overwatch2.ALL_SEASONS', 'indexFilterSet': False, 'parsedQuery': {'Role': {'$eq': 'Support'}}, 'queryHash': '8F0D14DF', 'planCacheKey': '8AADE24F', 'maxIndexedOrSolutionsReached': False, 'maxIndexedAndSolutionsReached': False, 'maxScansToExplodeReached': False, 'winningPlan': {'stage': 'FETCH', 'inputStage': {'stage': 'IXSCAN', 'keyPattern': {'Role': 1}, 'indexName': 'Role_1', 'isMultiKey': False, 'multiKeyPaths': {'Role': []}, 'isUnique': False, 'isSparse': False, 'isPartial': False, 'indexVersion': 2, 'direction': 'forward', 'indexBounds': {'Role': ['["Support", "Support"]']}}}, 'rejectedPlans': []}, 'executionStats': {'executionSuccess': True, 'nReturned': 264, 'executionTimeMillis': 0, 'totalKeysExamined': 264, 'totalDocsExamined': 264, 'executionStages': {'stage': 'FETCH', 'nReturned': 264, 'executionTimeMillisEstimate': 1, 'works': 265, 'advanced': 264, 'needTime': 0, 'needYield': 0, 'saveState': 0, 'restoreState': 0, 'isEOF': 1, 'docsExamined': 264, 'alreadyHasObj': 0, 'inputStage': {'stage': 'IXSCAN', 'nReturned': 264, 'executionTimeMillisEstimate': 0, 'works': 265, 'advanced': 264, 'needTime': 0, 'needYield': 0, 'saveState': 0, 'restoreState': 0, 'isEOF': 1, 'keyPattern': {'Role': 1}, 'indexName': 'Role_1', 'isMultiKey': False, 'multiKeyPaths': {'Role': []}, 'isUnique': False, 'isSparse': False, 'isPartial': False, 'indexVersion': 2, 'direction': 'forward', 'indexBounds': {'Role': ['["Support", "Support"]']}, 'keysExamined': 264, 'seeks': 1, 'dupsTested': 0, 'dupsDropped': 0}}, 'allPlansExecution': []}, 'command': {'find': 'ALL_SEASONS', 'filter': {'Role': 'Support'}, '$db': 'Overwatch2'}, 'serverInfo': {'host': 'ac-ov3tc7z-shard-00-02.crfcmgf.mongodb.net', 'port': 27017, 'version': '7.0.12', 'gitVersion': 'b6513ce0781db6818e24619e8a461eae90bc94fc'}, 'serverParameters': {'internalQueryFacetBufferSizeBytes': 104857600, 'internalQueryFacetMaxOutputDocSizeBytes': 104857600, 'internalLookupStageIntermediateDocumentMaxSizeBytes': 16793600, 'internalDocumentSourceGroupMaxMemoryBytes': 104857600, 'internalQueryMaxBlockingSortMemoryUsageBytes': 33554432, 'internalQueryProhibitBlockingMergeOnMongoS': 0, 'internalQueryMaxAddToSetBytes': 104857600, 'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600, 'internalQueryFrameworkControl': 'trySbeRestricted'}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1721829458, 33), 'signature': {'hash': b'L\x853\x1e58)8F\x93\x89\xc0K\xc6\x8a\xb1\x95\x80Z\xd9', 'keyId': 7340746313190866961}}, 'operationTime': Timestamp(1721829458, 33)}

# %% [markdown]
# Creare un dataframe Pandas con questi dati

# %%
import pandas as pd

data = list(all_seasons.aggregate(pipelineTotal))
df = pd.DataFrame(data)
df
# Out:
#               _id  avg_KDA_Ratio  avg_Win_Rate  avg_Damage_per_10min  \
# 0        Torbjorn       3.119375     53.474688           9491.062500
# 1        Symmetra       3.575000     52.545625           8287.343750
# 2        Ramattra       3.757083     51.030000           9559.291667
# 3       Reinhardt       3.020000     50.808125           8002.125000
# 4        Doomfist       3.242188     50.252812           7659.187500
# 5        Zenyatta       5.120000     49.922812           4802.156250
# 6           Sigma       4.771875     49.873125           9701.000000
# 7           Genji       2.494375     49.638438           7316.718750
# 8             Mei       3.895313     49.636250           6918.593750
# 9           Lucio       3.797188     49.445000           3525.000000
# 10       Brigitte       4.399063     49.287500           3605.531250
# 11            Ana       4.134062     49.090625           2576.000000
# 12   Junker Queen       4.139375     48.841563           8748.656250
# 13          Mercy       3.844063     48.526875            330.093750
# 14         Pharah       2.934063     48.213125           9092.093750
# 15           Ashe       2.628750     47.849063           8420.500000
# 16     Widowmaker       2.600000     47.775937           5860.375000
# 17         Reaper       2.676563     47.756250           8017.968750
# 18         Kiriko       4.700312     47.715625           2345.875000
# 19    Soldier: 76       2.918438     47.344062           8945.843750
# 20           D.Va       6.122500     47.330312           8279.156250
# 21          Moira       5.916250     47.210625           5231.437500
# 22           Echo       2.629375     47.165625           8164.250000
# 23         Tracer       2.465625     47.116563           6595.625000
# 24          Hanzo       2.968750     46.619062           7554.468750
# 25        Bastion       2.691250     46.520313           9990.000000
# 26        Junkrat       2.533437     46.350313           8227.937500
# 27       Baptiste       4.306250     46.289375           3548.312500
# 28          Zarya       4.424062     45.828750           9316.531250
# 29        Cassidy       2.177812     45.770938           8035.562500
# 30  Wrecking Ball       4.328437     45.200000           7499.656250
# 31        Sojourn       2.884688     44.325313           8407.062500
# 32        Winston       3.804688     44.228437           7632.187500
# 33          Orisa       3.585625     43.872188           9132.593750
# 34         Sombra       4.603438     42.640937           5376.687500
# 35        Roadhog       3.749062     41.961562           7982.406250
# 36     Lifeweaver       3.392500     38.455000            860.625000
#
#     avg_Healing_per_10min  avg_Deaths_per_10min
# 0                     NaN              6.964375
# 1                     NaN              8.020625
# 2                     NaN              6.655833
# 3                     NaN              7.125625
# 4                     NaN              7.808750
# 5              6199.12500              7.251250
# 6                     NaN              5.315313
# 7                     NaN              8.248437
# 8                     NaN              7.340000
# 9              7531.75000              7.504375
# 10             7801.56250              8.069688
# 11             8113.06250              6.277812
# 12                    NaN              7.116875
# 13             8773.12500              6.578437
# 14                    NaN              8.728125
# 15                    NaN              7.780625
# 16                    NaN              8.000937
# 17                    NaN              8.280313
# 18             8528.28125              6.118125
# 19             1345.56250              8.425000
# 20                    NaN              5.603125
# 21             9106.84375              6.392812
# 22                    NaN              8.218438
# 23                    NaN              8.306563
# 24                    NaN              8.127500
# 25                    NaN              8.451250
# 26                    NaN              8.529063
# 27             8568.93750              6.789062
# 28                    NaN              6.444375
# 29                    NaN              8.670938
# 30                    NaN              6.254688
# 31                    NaN              8.173750
# 32                    NaN              7.100000
# 33                    NaN              7.050000
# 34                    NaN              6.229375
# 35                    NaN              6.735625
# 36             8712.62500              6.107500
